# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

from files_02_channel import gamp_curve

snrdb, nmse = gamp_curve.nmse_data()

plt.plot(snrdb, nmse, ".-")
plt.grid()
plt.xlabel("SNR (dB)")
plt.ylabel("NMSE (dB)")
plt.title("EM-BG-GAMP algorithm")

# %%
from files_02_channel import dataset

data = dataset.data()

antenna_channel, angle_channel = (data.get(key) for key in ["Harray", "Hvirtual"])
fig1, axs1 = plt.subplots(3, 3)
fig2, axs2 = plt.subplots(3, 3)
for i, ax in enumerate(axs1.flat):
    ax.matshow(np.abs(antenna_channel[i]))
for i, ax in enumerate(axs2.flat):
    ax.matshow(np.abs(angle_channel[i]))

angle_ch = angle_channel[0]

antenna_ch = np.fft.fft(
    np.fft.ifft(angle_ch, axis=-2, norm="ortho"), axis=-1, norm="ortho"
)

print(f"sum = {np.sum(antenna_ch - antenna_channel[0])}")
# Out:
# sum = 0j

# %%
import tensorflow as tf
import math

# %%
def mse_db(y_true, y_pred):
    return (
        10
        * tf.math.log(tf.math.reduce_mean(tf.math.square(y_true - y_pred)))
        / math.log(10.0)
    )

# %%
from files_02_channel.lib.models import dense_model, residual_model
from tensorflow.keras.models import save_model, load_model


def get_model(Nr, Nt, T, model_type, should_include_x=False):
    if model_type == "dense":
        num_neurons = [256 for _ in range(10)]
        return dense_model(
            Nr,
            Nt,
            T,
            num_neurons,
            should_include_x=should_include_x,
            activation="tanh",
        )
    elif model_type == "residual":
        return residual_model(
            Nr, Nt, T, [400 for _ in range(3)], should_include_x=should_include_x
        )
    else:
        raise Exception("Invalid model name")

# %%
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)


def train(filename, training_generator=None, validation_generator=None, epochs=100):
    model = load_model(filename, custom_objects={"mse_db": mse_db})
    model.compile(loss=mse_db, optimizer="adam")
    history = model.fit(
        x=training_generator,
        validation_data=validation_generator,
        epochs=epochs,
        verbose=1,
        workers=1,
        use_multiprocessing=False,
        max_queue_size=16,
        callbacks=[
            EarlyStopping(
                monitor="val_loss",
                min_delta=5e-3,
                patience=9,
                restore_best_weights=True,
            ),
            ModelCheckpoint(
                filepath=filename,
                monitor="val_loss",
                verbose=1,
                save_best_only=True,
            ),
            ReduceLROnPlateau(
                factor=0.5,
                min_delta=5e-2,
                patience=3,
                cooldown=5,
                verbose=1,
                min_lr=1e-6,
            ),
            TensorBoard(histogram_freq=1),
        ],
    )

    return history

# %%
import files_02_channel.lib.snr_generator as snr_gen


def test_by_snr(model, snr, test_generator=None):
    test_generator.set_snr_generator(snr_gen.constant_snr(snr))
    return model.evaluate(test_generator)


def test(filename, test_generator, snr_db=[]):
    model = load_model(filename, custom_objects={"mse_db": mse_db})

    return [test_by_snr(model, snr, test_generator) for snr in snr_db]

# %%
from files_02_channel.lib.pilotgen.qpsk_pilot_gen import QpskPilotGenerator
from files_02_channel.lib.channelgen.random_sparse_gen import (
    RandomSparseChannelGenerator,
)

from files_02_channel.lib.XYGenerator import XYGenerator

rand_gen = np.random.Generator(np.random.SFC64())

Nr = 8
Nt = 8
T = 256

should_include_x = False

model = get_model(Nr, Nt, T, "residual", should_include_x=should_include_x)

model.compile(loss=mse_db, optimizer="adam")
model.summary()

filename = "model.h5"

save_model(model, filename)

x_generator = QpskPilotGenerator(Nt, T, rand_gen, is_constant=True)

snr_range = (0, 21)

num_clusters = 1
channel_generators = {
    name: RandomSparseChannelGenerator(Nr, Nt, num_clusters, rand_gen)
    for name in ["train", "val", "test"]
}

trainConfig = {
    "num_batches": 1000,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["train"],
    "snr_generator": snr_gen.uniform_snr(*snr_range, rand_gen),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}

valConfig = {
    "num_batches": 100,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["val"],
    "snr_generator": snr_gen.constant_snr(3),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}

testConfig = {
    "num_batches": 1000,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["test"],
    "snr_generator": snr_gen.uniform_snr(*snr_range, rand_gen),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 16)]    0           []
#
#  flatten (Flatten)              (None, 4096)         0           ['input_1[0][0]']
#
#  dense (Dense)                  (None, 400)          1638800     ['flatten[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 400)          0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 4496)         0           ['flatten[0][0]',
#                                                                   'leaky_re_lu[0][0]']
#
#  dense_1 (Dense)                (None, 400)          1798800     ['concatenate[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 400)          0           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 800)          0           ['leaky_re_lu[0][0]',
#                                                                   'leaky_re_lu_1[0][0]']
#
#  dense_2 (Dense)                (None, 400)          320400      ['concatenate_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 400)          0           ['dense_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 800)          0           ['leaky_re_lu_1[0][0]',
#                                                                   'leaky_re_lu_2[0][0]']
#
#  dense_3 (Dense)                (None, 128)          102528      ['concatenate_2[0][0]']
#
#  reshape (Reshape)              (None, 16, 8)        0           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 3,860,528
# Trainable params: 3,860,528
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train(
    filename,
    training_generator=XYGenerator(**trainConfig),
    validation_generator=XYGenerator(**valConfig),
    epochs=100,
)
# Out:
# Epoch 1/100
#  996/1000 [============================>.] - ETA: 0s - loss: -18.0156
# Epoch 1: val_loss improved from inf to -19.38853, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -18.0161 - val_loss: -19.3885 - lr: 0.0010
# Epoch 2/100
#  996/1000 [============================>.] - ETA: 0s - loss: -18.5417
# Epoch 2: val_loss did not improve from -19.38853
# 1000/1000 [==============================] - 9s 9ms/step - loss: -18.5407 - val_loss: -18.6384 - lr: 0.0010
# Epoch 3/100
# 1000/1000 [==============================] - ETA: 0s - loss: -18.9512
# Epoch 3: val_loss improved from -19.38853 to -19.83750, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -18.9512 - val_loss: -19.8375 - lr: 0.0010
# Epoch 4/100
# 1000/1000 [==============================] - ETA: 0s - loss: -18.5684
# Epoch 4: val_loss did not improve from -19.83750
# 1000/1000 [==============================] - 9s 9ms/step - loss: -18.5684 - val_loss: -19.2211 - lr: 0.0010
# Epoch 5/100
#  998/1000 [============================>.] - ETA: 0s - loss: -18.6945
# Epoch 5: val_loss did not improve from -19.83750
# 1000/1000 [==============================] - 9s 9ms/step - loss: -18.6953 - val_loss: -19.5153 - lr: 0.0010
# Epoch 6/100
# 1000/1000 [==============================] - ETA: 0s - loss: -19.1972
# Epoch 6: val_loss did not improve from -19.83750
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1000/1000 [==============================] - 9s 9ms/step - loss: -19.1972 - val_loss: -18.6971 - lr: 0.0010
# Epoch 7/100
#  998/1000 [============================>.] - ETA: 0s - loss: -21.7269
# Epoch 7: val_loss improved from -19.83750 to -22.54843, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -21.7296 - val_loss: -22.5484 - lr: 5.0000e-04
# Epoch 8/100
#  998/1000 [============================>.] - ETA: 0s - loss: -22.1914
# Epoch 8: val_loss improved from -22.54843 to -22.68671, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.1935 - val_loss: -22.6867 - lr: 5.0000e-04
# Epoch 9/100
#  999/1000 [============================>.] - ETA: 0s - loss: -22.2637
# Epoch 9: val_loss did not improve from -22.68671
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.2681 - val_loss: -22.5310 - lr: 5.0000e-04
# Epoch 10/100
# 1000/1000 [==============================] - ETA: 0s - loss: -22.4684
# Epoch 10: val_loss improved from -22.68671 to -23.41745, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.4684 - val_loss: -23.4175 - lr: 5.0000e-04
# Epoch 11/100
#  997/1000 [============================>.] - ETA: 0s - loss: -22.3755
# Epoch 11: val_loss did not improve from -23.41745
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.3770 - val_loss: -22.2858 - lr: 5.0000e-04
# Epoch 12/100
#  997/1000 [============================>.] - ETA: 0s - loss: -22.6258
# Epoch 12: val_loss did not improve from -23.41745
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.6343 - val_loss: -23.2524 - lr: 5.0000e-04
# Epoch 13/100
#  994/1000 [============================>.] - ETA: 0s - loss: -22.5557
# Epoch 13: val_loss did not improve from -23.41745
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1000/1000 [==============================] - 9s 9ms/step - loss: -22.5682 - val_loss: -22.5616 - lr: 5.0000e-04
# Epoch 14/100
#  999/1000 [============================>.] - ETA: 0s - loss: -24.2924
# Epoch 14: val_loss improved from -23.41745 to -24.49446, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.2987 - val_loss: -24.4945 - lr: 2.5000e-04
# Epoch 15/100
#  997/1000 [============================>.] - ETA: 0s - loss: -24.3790
# Epoch 15: val_loss did not improve from -24.49446
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.3681 - val_loss: -23.5601 - lr: 2.5000e-04
# Epoch 16/100
#  997/1000 [============================>.] - ETA: 0s - loss: -24.5213
# Epoch 16: val_loss improved from -24.49446 to -25.32820, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -24.5136 - val_loss: -25.3282 - lr: 2.5000e-04
# Epoch 17/100
#  999/1000 [============================>.] - ETA: 0s - loss: -24.7244
# Epoch 17: val_loss did not improve from -25.32820
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.7291 - val_loss: -24.6252 - lr: 2.5000e-04
# Epoch 18/100
#  997/1000 [============================>.] - ETA: 0s - loss: -24.6601
# Epoch 18: val_loss improved from -25.32820 to -25.81620, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.6461 - val_loss: -25.8162 - lr: 2.5000e-04
# Epoch 19/100
#  998/1000 [============================>.] - ETA: 0s - loss: -24.8614
# Epoch 19: val_loss did not improve from -25.81620
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.8586 - val_loss: -24.9366 - lr: 2.5000e-04
# Epoch 20/100
#  995/1000 [============================>.] - ETA: 0s - loss: -24.8524
# Epoch 20: val_loss did not improve from -25.81620
# 1000/1000 [==============================] - 10s 10ms/step - loss: -24.8545 - val_loss: -25.5093 - lr: 2.5000e-04
# Epoch 21/100
# 1000/1000 [==============================] - ETA: 0s - loss: -24.6446
# Epoch 21: val_loss did not improve from -25.81620
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1000/1000 [==============================] - 9s 9ms/step - loss: -24.6446 - val_loss: -25.1839 - lr: 2.5000e-04
# Epoch 22/100
#  996/1000 [============================>.] - ETA: 0s - loss: -26.2246
# Epoch 22: val_loss improved from -25.81620 to -27.83015, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.2438 - val_loss: -27.8302 - lr: 1.2500e-04
# Epoch 23/100
#  995/1000 [============================>.] - ETA: 0s - loss: -26.0051
# Epoch 23: val_loss did not improve from -27.83015
# 1000/1000 [==============================] - 10s 10ms/step - loss: -26.0070 - val_loss: -26.0466 - lr: 1.2500e-04
# Epoch 24/100
#  998/1000 [============================>.] - ETA: 0s - loss: -26.4622
# Epoch 24: val_loss did not improve from -27.83015
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.4715 - val_loss: -26.6933 - lr: 1.2500e-04
# Epoch 25/100
#  996/1000 [============================>.] - ETA: 0s - loss: -26.2368
# Epoch 25: val_loss did not improve from -27.83015
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.2223 - val_loss: -27.3718 - lr: 1.2500e-04
# Epoch 26/100
#  998/1000 [============================>.] - ETA: 0s - loss: -26.1879
# Epoch 26: val_loss did not improve from -27.83015
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.1943 - val_loss: -27.3064 - lr: 1.2500e-04
# Epoch 27/100
#  998/1000 [============================>.] - ETA: 0s - loss: -26.1196
# Epoch 27: val_loss improved from -27.83015 to -28.96990, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.1097 - val_loss: -28.9699 - lr: 1.2500e-04
# Epoch 28/100
# 1000/1000 [==============================] - ETA: 0s - loss: -26.4350
# Epoch 28: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.4350 - val_loss: -26.2973 - lr: 1.2500e-04
# Epoch 29/100
# 1000/1000 [==============================] - ETA: 0s - loss: -26.4235
# Epoch 29: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.4235 - val_loss: -26.8012 - lr: 1.2500e-04
# Epoch 30/100
#  998/1000 [============================>.] - ETA: 0s - loss: -26.3945
# Epoch 30: val_loss did not improve from -28.96990
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.3824 - val_loss: -27.0370 - lr: 1.2500e-04
# Epoch 31/100
#  997/1000 [============================>.] - ETA: 0s - loss: -26.9912
# Epoch 31: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.9978 - val_loss: -28.0430 - lr: 6.2500e-05
# Epoch 32/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.2401
# Epoch 32: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.2374 - val_loss: -26.9483 - lr: 6.2500e-05
# Epoch 33/100
#  998/1000 [============================>.] - ETA: 0s - loss: -27.4802
# Epoch 33: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.4789 - val_loss: -27.2903 - lr: 6.2500e-05
# Epoch 34/100
#  999/1000 [============================>.] - ETA: 0s - loss: -27.1478
# Epoch 34: val_loss did not improve from -28.96990
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.1536 - val_loss: -27.1406 - lr: 6.2500e-05
# Epoch 35/100
# 1000/1000 [==============================] - ETA: 0s - loss: -26.7951
# Epoch 35: val_loss improved from -28.96990 to -29.15503, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.7951 - val_loss: -29.1550 - lr: 6.2500e-05
# Epoch 36/100
#  996/1000 [============================>.] - ETA: 0s - loss: -26.9067
# Epoch 36: val_loss did not improve from -29.15503
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.8962 - val_loss: -27.2855 - lr: 6.2500e-05
# Epoch 37/100
#  999/1000 [============================>.] - ETA: 0s - loss: -26.7353
# Epoch 37: val_loss improved from -29.15503 to -29.65473, saving model to model.h5
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.7439 - val_loss: -29.6547 - lr: 6.2500e-05
# Epoch 38/100
#  996/1000 [============================>.] - ETA: 0s - loss: -26.9636
# Epoch 38: val_loss did not improve from -29.65473
# 1000/1000 [==============================] - 9s 9ms/step - loss: -26.9716 - val_loss: -28.2783 - lr: 6.2500e-05
# Epoch 39/100
#  995/1000 [============================>.] - ETA: 0s - loss: -27.0311
# Epoch 39: val_loss did not improve from -29.65473
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.0342 - val_loss: -26.6170 - lr: 6.2500e-05
# Epoch 40/100
#  998/1000 [============================>.] - ETA: 0s - loss: -27.1141
# Epoch 40: val_loss did not improve from -29.65473
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.1070 - val_loss: -27.3870 - lr: 6.2500e-05
# Epoch 41/100
#  996/1000 [============================>.] - ETA: 0s - loss: -27.4717
# Epoch 41: val_loss did not improve from -29.65473
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.4796 - val_loss: -29.6089 - lr: 3.1250e-05
# Epoch 42/100
#  999/1000 [============================>.] - ETA: 0s - loss: -27.5526
# Epoch 42: val_loss did not improve from -29.65473
# 1000/1000 [==============================] - 9s 9ms/step - loss: -27.5403 - val_loss: -29.5766 - lr: 3.1250e-05
# Epoch 43/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.4570
# Epoch 43: val_loss did not improve from -29.65473
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.4604 - val_loss: -28.2391 - lr: 3.1250e-05
# Epoch 44/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.3794
# Epoch 44: val_loss improved from -29.65473 to -29.93638, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.3768 - val_loss: -29.9364 - lr: 3.1250e-05
# Epoch 45/100
# 1000/1000 [==============================] - ETA: 0s - loss: -27.8657
# Epoch 45: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 11s 11ms/step - loss: -27.8657 - val_loss: -29.2164 - lr: 3.1250e-05
# Epoch 46/100
# 1000/1000 [==============================] - ETA: 0s - loss: -27.5157
# Epoch 46: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 11s 11ms/step - loss: -27.5157 - val_loss: -29.0602 - lr: 3.1250e-05
# Epoch 47/100
#  995/1000 [============================>.] - ETA: 0s - loss: -27.7992
# Epoch 47: val_loss did not improve from -29.93638
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.7941 - val_loss: -28.9317 - lr: 3.1250e-05
# Epoch 48/100
# 1000/1000 [==============================] - ETA: 0s - loss: -27.5562
# Epoch 48: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.5562 - val_loss: -28.2528 - lr: 1.5625e-05
# Epoch 49/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.0954
# Epoch 49: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.0784 - val_loss: -29.8913 - lr: 1.5625e-05
# Epoch 50/100
#  998/1000 [============================>.] - ETA: 0s - loss: -27.6755
# Epoch 50: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.6704 - val_loss: -29.4473 - lr: 1.5625e-05
# Epoch 51/100
# 1000/1000 [==============================] - ETA: 0s - loss: -27.5034
# Epoch 51: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.5034 - val_loss: -29.6824 - lr: 1.5625e-05
# Epoch 52/100
#  999/1000 [============================>.] - ETA: 0s - loss: -27.6090
# Epoch 52: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.6057 - val_loss: -29.2918 - lr: 1.5625e-05
# Epoch 53/100
#  999/1000 [============================>.] - ETA: 0s - loss: -27.4439
# Epoch 53: val_loss did not improve from -29.93638
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.4427 - val_loss: -28.9478 - lr: 1.5625e-05

# %%
nmse_db = test(
    filename,
    test_generator=XYGenerator(**testConfig),
    snr_db=np.arange(-30, 31, 3),
)
# Out:
# 1000/1000 [==============================] - 5s 5ms/step - loss: -4.7189
# 1000/1000 [==============================] - 5s 5ms/step - loss: -6.0223
# 1000/1000 [==============================] - 5s 5ms/step - loss: -7.8852
# 1000/1000 [==============================] - 5s 5ms/step - loss: -10.4008
# 1000/1000 [==============================] - 5s 5ms/step - loss: -13.5469
# 1000/1000 [==============================] - 5s 5ms/step - loss: -17.1103
# 1000/1000 [==============================] - 5s 5ms/step - loss: -20.6218
# 1000/1000 [==============================] - 5s 5ms/step - loss: -23.4380
# 1000/1000 [==============================] - 5s 5ms/step - loss: -25.1756
# 1000/1000 [==============================] - 5s 5ms/step - loss: -26.5879
# 1000/1000 [==============================] - 5s 4ms/step - loss: -27.6387
# 1000/1000 [==============================] - 5s 5ms/step - loss: -28.8021
# 1000/1000 [==============================] - 5s 5ms/step - loss: -28.6944
# 1000/1000 [==============================] - 5s 4ms/step - loss: -28.5610
# 1000/1000 [==============================] - 5s 5ms/step - loss: -27.6235
# 1000/1000 [==============================] - 5s 5ms/step - loss: -26.7920
# 1000/1000 [==============================] - 4s 4ms/step - loss: -26.4713
# 1000/1000 [==============================] - 5s 5ms/step - loss: -26.1825
# 1000/1000 [==============================] - 5s 4ms/step - loss: -25.7986
# 1000/1000 [==============================] - 4s 4ms/step - loss: -25.8905
# 1000/1000 [==============================] - 5s 4ms/step - loss: -25.6563

# %%
fig_res, ax_res = plt.subplots()
ax_res.plot(snrdb, nmse)
ax_res.plot(np.arange(-30, 31, 3), nmse_db)
ax_res.legend(["EM-BG-GAMP", "DL approach"])
