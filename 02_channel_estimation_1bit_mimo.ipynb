# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

from files_02_channel import gamp_curve

snrdb, nmse = gamp_curve.nmse_data()

plt.plot(snrdb, nmse, ".-")
plt.grid()
plt.xlabel("SNR (dB)")
plt.ylabel("NMSE (dB)")
plt.title("EM-BG-GAMP algorithm")
# Out:
# Text(0.5, 1.0, 'EM-BG-GAMP algorithm')

# %%
from files_02_channel import dataset

data = dataset.data()

antenna_channel, angle_channel = (data.get(key) for key in ["Harray", "Hvirtual"])
fig1, axs1 = plt.subplots(3, 3)
fig2, axs2 = plt.subplots(3, 3)
for i, ax in enumerate(axs1.flat):
    ax.matshow(np.abs(antenna_channel[i]))
for i, ax in enumerate(axs2.flat):
    ax.matshow(np.abs(angle_channel[i]))

angle_ch = angle_channel[0]

antenna_ch = np.fft.fft(
    np.fft.ifft(angle_ch, axis=-2, norm="ortho"), axis=-1, norm="ortho"
)

print(f"sum = {np.sum(antenna_ch - antenna_channel[0])}")
# Out:
# sum = 0j

# %%
import tensorflow as tf
import math

# %%
def mse_db(y_true, y_pred):
    return (
        10
        * tf.math.log(tf.math.reduce_mean(tf.math.square(y_true - y_pred)))
        / math.log(10.0)
    )

# %%
from files_02_channel.low_res_mimo_ch_est.models import dense_model, residual_model
from tensorflow.keras.models import save_model, load_model


def get_model(Nr, Nt, T, model_type, should_include_x=False):
    if model_type == "dense":
        num_neurons = [256 for _ in range(10)]
        return dense_model(
            Nr,
            Nt,
            T,
            num_neurons,
            should_include_x=should_include_x,
            activation="tanh",
        )
    elif model_type == "residual":
        return residual_model(
            Nr, Nt, T, [400 for _ in range(3)], should_include_x=should_include_x
        )
    else:
        raise Exception("Invalid model name")

# %%
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau,
    TensorBoard,
)


def train(filename, training_generator=None, validation_generator=None, epochs=100):
    model = load_model(filename, custom_objects={"mse_db": mse_db})
    model.compile(loss=mse_db, optimizer="adam")
    history = model.fit(
        x=training_generator,
        validation_data=validation_generator,
        epochs=epochs,
        verbose=1,
        workers=1,
        use_multiprocessing=False,
        max_queue_size=16,
        callbacks=[
            EarlyStopping(
                monitor="val_loss",
                min_delta=5e-3,
                patience=9,
                restore_best_weights=True,
            ),
            ModelCheckpoint(
                filepath=filename,
                monitor="val_loss",
                verbose=1,
                save_best_only=True,
            ),
            ReduceLROnPlateau(
                factor=0.5,
                min_delta=5e-2,
                patience=3,
                cooldown=5,
                verbose=1,
                min_lr=1e-6,
            ),
            TensorBoard(histogram_freq=1),
        ],
    )

    return history

# %%
import files_02_channel.low_res_mimo_ch_est.snr_generator as snr_gen


def test_by_snr(model, snr, test_generator=None):
    test_generator.set_snr_generator(snr_gen.constant_snr(snr))
    return model.evaluate(test_generator)


def test(filename, test_generator, snr_db=[]):
    model = load_model(filename, custom_objects={"mse_db": mse_db})

    return [test_by_snr(model, snr, test_generator) for snr in snr_db]

# %%
from files_02_channel.low_res_mimo_ch_est.pilotgen.qpsk_pilot_gen import QpskPilotGenerator
from files_02_channel.low_res_mimo_ch_est.channelgen.random_sparse_gen import (
    RandomSparseChannelGenerator,
)

from files_02_channel.low_res_mimo_ch_est.XYGenerator import XYGenerator

rand_gen = np.random.Generator(np.random.SFC64())

Nr = 8
Nt = 8
T = 256

should_include_x = False

model = get_model(Nr, Nt, T, "residual", should_include_x=should_include_x)

model.compile(loss=mse_db, optimizer="adam")
model.summary()

filename = "model.h5"

save_model(model, filename)

x_generator = QpskPilotGenerator(Nt, T, rand_gen, is_constant=True)

snr_range = (0, 21)

num_clusters = 1
channel_generators = {
    name: RandomSparseChannelGenerator(Nr, Nt, num_clusters, rand_gen)
    for name in ["train", "val", "test"]
}

trainConfig = {
    "num_batches": 1000,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["train"],
    "snr_generator": snr_gen.uniform_snr(*snr_range, rand_gen),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}

valConfig = {
    "num_batches": 100,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["val"],
    "snr_generator": snr_gen.constant_snr(3),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}

testConfig = {
    "num_batches": 1000,
    "batch_size": 32,
    "x_generator": x_generator,
    "channel_generator": channel_generators["test"],
    "snr_generator": snr_gen.uniform_snr(*snr_range, rand_gen),
    "quantizer": np.sign,
    "constant_batches": False,
    "should_include_x": should_include_x,
    "generator": rand_gen,
}
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 16)]    0           []
#
#  flatten (Flatten)              (None, 4096)         0           ['input_1[0][0]']
#
#  dense (Dense)                  (None, 400)          1638800     ['flatten[0][0]']
#
#  leaky_re_lu (LeakyReLU)        (None, 400)          0           ['dense[0][0]']
#
#  concatenate (Concatenate)      (None, 4496)         0           ['flatten[0][0]',
#                                                                   'leaky_re_lu[0][0]']
#
#  dense_1 (Dense)                (None, 400)          1798800     ['concatenate[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)      (None, 400)          0           ['dense_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 800)          0           ['leaky_re_lu[0][0]',
#                                                                   'leaky_re_lu_1[0][0]']
#
#  dense_2 (Dense)                (None, 400)          320400      ['concatenate_1[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)      (None, 400)          0           ['dense_2[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 800)          0           ['leaky_re_lu_1[0][0]',
#                                                                   'leaky_re_lu_2[0][0]']
#
#  dense_3 (Dense)                (None, 128)          102528      ['concatenate_2[0][0]']
#
#  reshape (Reshape)              (None, 16, 8)        0           ['dense_3[0][0]']
#
# ==================================================================================================
# Total params: 3,860,528
# Trainable params: 3,860,528
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
train(
    filename,
    training_generator=XYGenerator(**trainConfig),
    validation_generator=XYGenerator(**valConfig),
    epochs=100,
)
# Out:
# Epoch 1/100
# 2022-09-06 14:29:11.318875: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#  998/1000 [============================>.] - ETA: 0s - loss: -10.8007
# Epoch 1: val_loss improved from inf to -12.99279, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -10.8045 - val_loss: -12.9928 - lr: 0.0010
# Epoch 2/100
# 1000/1000 [==============================] - ETA: 0s - loss: -13.8526
# Epoch 2: val_loss improved from -12.99279 to -14.42486, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -13.8526 - val_loss: -14.4249 - lr: 0.0010
# Epoch 3/100
# 1000/1000 [==============================] - ETA: 0s - loss: -14.7661
# Epoch 3: val_loss improved from -14.42486 to -15.46465, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -14.7661 - val_loss: -15.4647 - lr: 0.0010
# Epoch 4/100
#  998/1000 [============================>.] - ETA: 0s - loss: -15.5965
# Epoch 4: val_loss improved from -15.46465 to -16.07193, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -15.5974 - val_loss: -16.0719 - lr: 0.0010
# Epoch 5/100
#  995/1000 [============================>.] - ETA: 0s - loss: -16.1003
# Epoch 5: val_loss improved from -16.07193 to -16.69714, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -16.1025 - val_loss: -16.6971 - lr: 0.0010
# Epoch 6/100
#  996/1000 [============================>.] - ETA: 0s - loss: -17.0234
# Epoch 6: val_loss improved from -16.69714 to -17.15092, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -17.0209 - val_loss: -17.1509 - lr: 0.0010
# Epoch 7/100
#  997/1000 [============================>.] - ETA: 0s - loss: -17.8069
# Epoch 7: val_loss improved from -17.15092 to -18.10004, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -17.8088 - val_loss: -18.1000 - lr: 0.0010
# Epoch 8/100
#  997/1000 [============================>.] - ETA: 0s - loss: -17.6494
# Epoch 8: val_loss did not improve from -18.10004
# 1000/1000 [==============================] - 10s 10ms/step - loss: -17.6495 - val_loss: -17.4995 - lr: 0.0010
# Epoch 9/100
#  998/1000 [============================>.] - ETA: 0s - loss: -18.4352
# Epoch 9: val_loss improved from -18.10004 to -18.30621, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -18.4365 - val_loss: -18.3062 - lr: 0.0010
# Epoch 10/100
#  996/1000 [============================>.] - ETA: 0s - loss: -18.8631
# Epoch 10: val_loss improved from -18.30621 to -19.37655, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -18.8627 - val_loss: -19.3766 - lr: 0.0010
# Epoch 11/100
#  997/1000 [============================>.] - ETA: 0s - loss: -18.7101
# Epoch 11: val_loss did not improve from -19.37655
# 1000/1000 [==============================] - 10s 10ms/step - loss: -18.7128 - val_loss: -19.2588 - lr: 0.0010
# Epoch 12/100
# 1000/1000 [==============================] - ETA: 0s - loss: -19.1092
# Epoch 12: val_loss improved from -19.37655 to -19.85994, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -19.1092 - val_loss: -19.8599 - lr: 0.0010
# Epoch 13/100
#  998/1000 [============================>.] - ETA: 0s - loss: -18.9874
# Epoch 13: val_loss improved from -19.85994 to -19.86510, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -18.9918 - val_loss: -19.8651 - lr: 0.0010
# Epoch 14/100
#  997/1000 [============================>.] - ETA: 0s - loss: -19.4228
# Epoch 14: val_loss improved from -19.86510 to -19.97620, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -19.4229 - val_loss: -19.9762 - lr: 0.0010
# Epoch 15/100
# 1000/1000 [==============================] - ETA: 0s - loss: -19.4680
# Epoch 15: val_loss did not improve from -19.97620
# 1000/1000 [==============================] - 10s 10ms/step - loss: -19.4680 - val_loss: -19.6173 - lr: 0.0010
# Epoch 16/100
#  995/1000 [============================>.] - ETA: 0s - loss: -19.5076
# Epoch 16: val_loss did not improve from -19.97620
# 1000/1000 [==============================] - 10s 10ms/step - loss: -19.5073 - val_loss: -19.2154 - lr: 0.0010
# Epoch 17/100
#  997/1000 [============================>.] - ETA: 0s - loss: -19.5721
# Epoch 17: val_loss did not improve from -19.97620
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -19.5716 - val_loss: -19.8705 - lr: 0.0010
# Epoch 18/100
#  999/1000 [============================>.] - ETA: 0s - loss: -22.6294
# Epoch 18: val_loss improved from -19.97620 to -22.73547, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -22.6317 - val_loss: -22.7355 - lr: 5.0000e-04
# Epoch 19/100
# 1000/1000 [==============================] - ETA: 0s - loss: -23.1404
# Epoch 19: val_loss improved from -22.73547 to -23.10129, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.1404 - val_loss: -23.1013 - lr: 5.0000e-04
# Epoch 20/100
#  998/1000 [============================>.] - ETA: 0s - loss: -23.2616
# Epoch 20: val_loss improved from -23.10129 to -24.12231, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.2584 - val_loss: -24.1223 - lr: 5.0000e-04
# Epoch 21/100
# 1000/1000 [==============================] - ETA: 0s - loss: -23.2940
# Epoch 21: val_loss did not improve from -24.12231
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.2940 - val_loss: -23.7611 - lr: 5.0000e-04
# Epoch 22/100
#  995/1000 [============================>.] - ETA: 0s - loss: -23.4945
# Epoch 22: val_loss did not improve from -24.12231
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.4830 - val_loss: -24.0928 - lr: 5.0000e-04
# Epoch 23/100
#  999/1000 [============================>.] - ETA: 0s - loss: -23.6666
# Epoch 23: val_loss did not improve from -24.12231
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.6606 - val_loss: -22.8914 - lr: 5.0000e-04
# Epoch 24/100
#  996/1000 [============================>.] - ETA: 0s - loss: -23.7714
# Epoch 24: val_loss did not improve from -24.12231
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -23.7796 - val_loss: -23.9452 - lr: 5.0000e-04
# Epoch 25/100
#  997/1000 [============================>.] - ETA: 0s - loss: -25.6070
# Epoch 25: val_loss improved from -24.12231 to -26.70644, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -25.6074 - val_loss: -26.7064 - lr: 2.5000e-04
# Epoch 26/100
#  997/1000 [============================>.] - ETA: 0s - loss: -25.8227
# Epoch 26: val_loss did not improve from -26.70644
# 1000/1000 [==============================] - 10s 10ms/step - loss: -25.8342 - val_loss: -26.1932 - lr: 2.5000e-04
# Epoch 27/100
#  995/1000 [============================>.] - ETA: 0s - loss: -26.1561
# Epoch 27: val_loss did not improve from -26.70644
# 1000/1000 [==============================] - 10s 10ms/step - loss: -26.1360 - val_loss: -26.3635 - lr: 2.5000e-04
# Epoch 28/100
#  998/1000 [============================>.] - ETA: 0s - loss: -25.9264
# Epoch 28: val_loss did not improve from -26.70644
# 1000/1000 [==============================] - 10s 10ms/step - loss: -25.9236 - val_loss: -26.6076 - lr: 2.5000e-04
# Epoch 29/100
#  997/1000 [============================>.] - ETA: 0s - loss: -26.0305
# Epoch 29: val_loss did not improve from -26.70644
# 1000/1000 [==============================] - 10s 10ms/step - loss: -26.0386 - val_loss: -26.5801 - lr: 2.5000e-04
# Epoch 30/100
# 1000/1000 [==============================] - ETA: 0s - loss: -26.1747
# Epoch 30: val_loss did not improve from -26.70644
# 1000/1000 [==============================] - 10s 10ms/step - loss: -26.1747 - val_loss: -26.4033 - lr: 2.5000e-04
# Epoch 31/100
#  996/1000 [============================>.] - ETA: 0s - loss: -26.3066
# Epoch 31: val_loss did not improve from -26.70644
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -26.2967 - val_loss: -26.6353 - lr: 2.5000e-04
# Epoch 32/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.5998
# Epoch 32: val_loss improved from -26.70644 to -27.92367, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.5987 - val_loss: -27.9237 - lr: 1.2500e-04
# Epoch 33/100
#  999/1000 [============================>.] - ETA: 0s - loss: -27.9343
# Epoch 33: val_loss did not improve from -27.92367
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.9319 - val_loss: -27.8400 - lr: 1.2500e-04
# Epoch 34/100
#  996/1000 [============================>.] - ETA: 0s - loss: -28.0471
# Epoch 34: val_loss improved from -27.92367 to -28.74924, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.0300 - val_loss: -28.7492 - lr: 1.2500e-04
# Epoch 35/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.8221
# Epoch 35: val_loss improved from -28.74924 to -29.00038, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.8169 - val_loss: -29.0004 - lr: 1.2500e-04
# Epoch 36/100
#  997/1000 [============================>.] - ETA: 0s - loss: -27.5780
# Epoch 36: val_loss did not improve from -29.00038
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.5875 - val_loss: -28.6485 - lr: 1.2500e-04
# Epoch 37/100
#  996/1000 [============================>.] - ETA: 0s - loss: -27.9172
# Epoch 37: val_loss did not improve from -29.00038
# 1000/1000 [==============================] - 10s 10ms/step - loss: -27.9038 - val_loss: -28.3758 - lr: 1.2500e-04
# Epoch 38/100
# 1000/1000 [==============================] - ETA: 0s - loss: -28.0477
# Epoch 38: val_loss did not improve from -29.00038
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.0477 - val_loss: -27.8130 - lr: 1.2500e-04
# Epoch 39/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.7018
# Epoch 39: val_loss improved from -29.00038 to -29.96140, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.7106 - val_loss: -29.9614 - lr: 6.2500e-05
# Epoch 40/100
#  996/1000 [============================>.] - ETA: 0s - loss: -28.6606
# Epoch 40: val_loss did not improve from -29.96140
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.6675 - val_loss: -29.5919 - lr: 6.2500e-05
# Epoch 41/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.3571
# Epoch 41: val_loss did not improve from -29.96140
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.3500 - val_loss: -29.8720 - lr: 6.2500e-05
# Epoch 42/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.3365
# Epoch 42: val_loss did not improve from -29.96140
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.3215 - val_loss: -28.9528 - lr: 6.2500e-05
# Epoch 43/100
#  998/1000 [============================>.] - ETA: 0s - loss: -28.7655
# Epoch 43: val_loss improved from -29.96140 to -30.02369, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.7672 - val_loss: -30.0237 - lr: 6.2500e-05
# Epoch 44/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.5261
# Epoch 44: val_loss did not improve from -30.02369
# 1000/1000 [==============================] - 9s 9ms/step - loss: -28.5347 - val_loss: -28.6686 - lr: 6.2500e-05
# Epoch 45/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.5822
# Epoch 45: val_loss did not improve from -30.02369
# 1000/1000 [==============================] - 10s 9ms/step - loss: -28.5710 - val_loss: -29.9647 - lr: 6.2500e-05
# Epoch 46/100
#  996/1000 [============================>.] - ETA: 0s - loss: -28.5527
# Epoch 46: val_loss improved from -30.02369 to -30.32782, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.5376 - val_loss: -30.3278 - lr: 6.2500e-05
# Epoch 47/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.0086
# Epoch 47: val_loss did not improve from -30.32782
# 1000/1000 [==============================] - 9s 9ms/step - loss: -28.9947 - val_loss: -29.7548 - lr: 6.2500e-05
# Epoch 48/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.6663
# Epoch 48: val_loss improved from -30.32782 to -30.70066, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.6544 - val_loss: -30.7007 - lr: 6.2500e-05
# Epoch 49/100
#  996/1000 [============================>.] - ETA: 0s - loss: -28.7637
# Epoch 49: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.7831 - val_loss: -30.1652 - lr: 6.2500e-05
# Epoch 50/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.9214
# Epoch 50: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.9234 - val_loss: -29.7383 - lr: 6.2500e-05
# Epoch 51/100
#  997/1000 [============================>.] - ETA: 0s - loss: -28.6985
# Epoch 51: val_loss did not improve from -30.70066
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.6873 - val_loss: -28.1111 - lr: 6.2500e-05
# Epoch 52/100
#  996/1000 [============================>.] - ETA: 0s - loss: -28.5820
# Epoch 52: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.5916 - val_loss: -30.5460 - lr: 3.1250e-05
# Epoch 53/100
#  995/1000 [============================>.] - ETA: 0s - loss: -29.3460
# Epoch 53: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.3498 - val_loss: -29.9554 - lr: 3.1250e-05
# Epoch 54/100
#  999/1000 [============================>.] - ETA: 0s - loss: -29.0101
# Epoch 54: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.0013 - val_loss: -29.7857 - lr: 3.1250e-05
# Epoch 55/100
#  995/1000 [============================>.] - ETA: 0s - loss: -29.0987
# Epoch 55: val_loss did not improve from -30.70066
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.1101 - val_loss: -30.4935 - lr: 3.1250e-05
# Epoch 56/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.1784
# Epoch 56: val_loss improved from -30.70066 to -30.86630, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.1739 - val_loss: -30.8663 - lr: 3.1250e-05
# Epoch 57/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.4200
# Epoch 57: val_loss did not improve from -30.86630
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.4139 - val_loss: -30.8035 - lr: 3.1250e-05
# Epoch 58/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.1928
# Epoch 58: val_loss did not improve from -30.86630
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.1964 - val_loss: -30.4888 - lr: 3.1250e-05
# Epoch 59/100
#  999/1000 [============================>.] - ETA: 0s - loss: -28.9457
# Epoch 59: val_loss improved from -30.86630 to -31.22572, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -28.9506 - val_loss: -31.2257 - lr: 3.1250e-05
# Epoch 60/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.1060
# Epoch 60: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.0994 - val_loss: -31.0377 - lr: 3.1250e-05
# Epoch 61/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.2835
# Epoch 61: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.2976 - val_loss: -29.3217 - lr: 3.1250e-05
# Epoch 62/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.1491
# Epoch 62: val_loss did not improve from -31.22572
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.1531 - val_loss: -30.7328 - lr: 3.1250e-05
# Epoch 63/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.0381
# Epoch 63: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.0221 - val_loss: -30.7547 - lr: 1.5625e-05
# Epoch 64/100
#  995/1000 [============================>.] - ETA: 0s - loss: -29.5384
# Epoch 64: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.5375 - val_loss: -31.0671 - lr: 1.5625e-05
# Epoch 65/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.4035
# Epoch 65: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.4153 - val_loss: -29.8849 - lr: 1.5625e-05
# Epoch 66/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.5141
# Epoch 66: val_loss did not improve from -31.22572
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.5316 - val_loss: -30.5427 - lr: 1.5625e-05
# Epoch 67/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.7718
# Epoch 67: val_loss improved from -31.22572 to -32.03428, saving model to model.h5
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.7772 - val_loss: -32.0343 - lr: 1.5625e-05
# Epoch 68/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.2467
# Epoch 68: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.2541 - val_loss: -30.6492 - lr: 1.5625e-05
# Epoch 69/100
#  999/1000 [============================>.] - ETA: 0s - loss: -29.0753
# Epoch 69: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.0804 - val_loss: -30.8861 - lr: 1.5625e-05
# Epoch 70/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.8901
# Epoch 70: val_loss did not improve from -32.03428
#
# Epoch 70: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.9012 - val_loss: -30.3751 - lr: 1.5625e-05
# Epoch 71/100
#  995/1000 [============================>.] - ETA: 0s - loss: -29.4821
# Epoch 71: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.5024 - val_loss: -29.7720 - lr: 7.8125e-06
# Epoch 72/100
#  997/1000 [============================>.] - ETA: 0s - loss: -29.4637
# Epoch 72: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.4530 - val_loss: -30.0083 - lr: 7.8125e-06
# Epoch 73/100
#  996/1000 [============================>.] - ETA: 0s - loss: -29.7933
# Epoch 73: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.7981 - val_loss: -31.0834 - lr: 7.8125e-06
# Epoch 74/100
#  999/1000 [============================>.] - ETA: 0s - loss: -29.5148
# Epoch 74: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.5155 - val_loss: -31.1303 - lr: 7.8125e-06
# Epoch 75/100
# 1000/1000 [==============================] - ETA: 0s - loss: -29.6440
# Epoch 75: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.6440 - val_loss: -30.4584 - lr: 7.8125e-06
# Epoch 76/100
#  995/1000 [============================>.] - ETA: 0s - loss: -29.6625
# Epoch 76: val_loss did not improve from -32.03428
# 1000/1000 [==============================] - 10s 10ms/step - loss: -29.6493 - val_loss: -31.3711 - lr: 7.8125e-06

# %%
nmse_db = test(
    filename,
    test_generator=XYGenerator(**testConfig),
    snr_db=np.arange(-30, 31, 3),
)
# Out:
# 1000/1000 [==============================] - 5s 5ms/step - loss: -4.6134
# 1000/1000 [==============================] - 5s 5ms/step - loss: -5.8960
# 1000/1000 [==============================] - 5s 5ms/step - loss: -7.7463
# 1000/1000 [==============================] - 5s 5ms/step - loss: -10.2767
# 1000/1000 [==============================] - 5s 5ms/step - loss: -13.4843
# 1000/1000 [==============================] - 5s 5ms/step - loss: -17.2965
# 1000/1000 [==============================] - 5s 5ms/step - loss: -21.3356
# 1000/1000 [==============================] - 5s 5ms/step - loss: -24.7559
# 1000/1000 [==============================] - 5s 5ms/step - loss: -26.8552
# 1000/1000 [==============================] - 5s 5ms/step - loss: -28.3163
# 1000/1000 [==============================] - 5s 5ms/step - loss: -29.5174
# 1000/1000 [==============================] - 5s 5ms/step - loss: -30.8894
# 1000/1000 [==============================] - 5s 5ms/step - loss: -30.6560
# 1000/1000 [==============================] - 5s 5ms/step - loss: -30.4079
# 1000/1000 [==============================] - 5s 5ms/step - loss: -29.4765
# 1000/1000 [==============================] - 5s 5ms/step - loss: -28.8351
# 1000/1000 [==============================] - 5s 5ms/step - loss: -28.2879
# 1000/1000 [==============================] - 5s 5ms/step - loss: -27.8156
# 1000/1000 [==============================] - 5s 5ms/step - loss: -27.7849
# 1000/1000 [==============================] - 5s 5ms/step - loss: -27.4840
# 1000/1000 [==============================] - 5s 5ms/step - loss: -27.3880

# %%
fig_res, ax_res = plt.subplots()
ax_res.plot(snrdb, nmse)
ax_res.plot(np.arange(-30, 31, 3), nmse_db)
ax_res.legend(["EM-BG-GAMP", "DL approach"])
